# %% [markdown]
# <h3>Objective</h3>

# %% [markdown]
# <p>
# The objective of this project is to perform classification on "Wine Quality" Dataset.
# </p>

# %% [markdown]
# <h4>Import Libraries</h4>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h4>Read Data</h4>

# %%
df = pd.read_csv(r'A:\1 - Study Files\100 - INT\Coders Arts\Task 1\Wine Quality\Wine Quality\wine+quality\winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# <h3>Data Cleaning</h3>

# %% [markdown]
# <h5>1. Dropping Irrelevant Columns</h5>
# <p> There are no Irrelevant columns in this dataset</p>

# %% [markdown]
# <h5>2. Renaming Columns</h5>
# <p> No need to rename columns in this dataset</p>

# %% [markdown]
# <h5>3. Formatting Data</h5>
# <p> No need to format data in this dataset</p>

# %% [markdown]
# <h5>4. Duplicate Data</h5>

# %%
df_duplicates = df[df.duplicated(keep = "first")]
df_duplicates
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (1359, 12)

# %% [markdown]
# <p>Duplicate rows removed !</p>

# %% [markdown]
# <h5>5. Dealing with Missing Values</h5>

# %%
Missing_values = df.isnull().sum()
Missing_values
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# <p>No missing values !</p>

# %% [markdown]
# <h5>6. Dealing with Data types</h5>

# %%
df.head(4)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# <p>Data types are correct for every column !</p>

# %% [markdown]
# <h3>Exploratory Data Analysis</h3>

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %%
# The Target variable
df["quality"]
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 5       5
#        ..
# 1593    6
# 1594    5
# 1595    6
# 1597    5
# 1598    6
# Name: quality, Length: 1359, dtype: int64

# %%
df["quality"].nunique()
# Out:
# 6

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
sns.boxplot(x="quality",y="fixed acidity",data=df)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
sns.boxplot(x="quality",y="citric acid",data=df)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# Model

# %%
X = df.drop("quality",axis = 1)
y = df["quality"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
fit=mm.fit(X_train)
X_train=fit.transform(X_train)
X_test=fit.transform(X_test)

# %%
#SVM Classifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

random= SVC()
fit=random.fit(X_train,y_train)

score=random.score(X_test,y_test)
print('The score of the model is : ',score)
predict=random.predict(X_test)
print(classification_report(predict,y_test))
# Out:
# The score of the model is :  0.5808823529411765
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.73      0.65      0.69       126
#            6       0.65      0.52      0.58       134
#            7       0.16      0.50      0.24        12
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.58       272
#    macro avg       0.26      0.28      0.25       272
# weighted avg       0.66      0.58      0.61       272
# c:\Users\Dixon\Python Environments\main\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

random= DecisionTreeClassifier()
fit=random.fit(X_train,y_train)

score=random.score(X_test,y_test)
print('The score of the model is : ',score)
predict=random.predict(X_test)
print(classification_report(predict,y_test))
# Out:
# The score of the model is :  0.46691176470588236
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         8
#            5       0.58      0.61      0.60       108
#            6       0.43      0.46      0.44        99
#            7       0.39      0.30      0.34        50
#            8       0.00      0.00      0.00         6
#
#     accuracy                           0.47       272
#    macro avg       0.23      0.23      0.23       272
# weighted avg       0.46      0.47      0.46       272

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

random=RandomForestClassifier()
fit=random.fit(X_train,y_train)

score=random.score(X_test,y_test)
print('The score of the model is : ',score)
predict=random.predict(X_test)
print(classification_report(predict,y_test))
# Out:
# The score of the model is :  0.5625
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.74      0.67      0.70       126
#            6       0.57      0.51      0.54       121
#            7       0.18      0.28      0.22        25
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.56       272
#    macro avg       0.25      0.24      0.24       272
# weighted avg       0.62      0.56      0.59       272
# c:\Users\Dixon\Python Environments\main\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# The accuracy of the wine quality prediction scores can be significantly improved by increasing the amount of fixed acidity, citric acid, sulfates, and alcohol, as well as decreasing the amount of volatile acidity and chlorides. As for the accuracy of the ML models themselves, it can be also enhanced by using a larger dataset with a greater balance between low- and high-quality wines.
